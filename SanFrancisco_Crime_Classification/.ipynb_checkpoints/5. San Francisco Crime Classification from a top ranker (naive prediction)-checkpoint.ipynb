# %% [markdown]
# Top ranker의 SF Crime Classification의 naive prediction입니다. train 데이터에서 각 Category의 비율을 test 데이터에 그대로 넣은 것입니다. 모든 row의 값은 동일합니다.

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
train = pd.read_csv('./data/train.csv', parse_dates=['Dates'])
test = pd.read_csv('./data/test.csv', parse_dates=['Dates'], index_col='Id')

# %% [markdown]
# ## Cleaning the train data

# %%
train.drop_duplicates(inplace=True)
train.replace({'X': -120.5, 'Y': 90.0}, np.NaN, inplace=True)

imp = SimpleImputer(strategy='mean')

for district in train['PdDistrict'].unique():
    train.loc[train['PdDistrict'] == district, ['X', 'Y']] = imp.fit_transform(
        train.loc[train['PdDistrict'] == district, ['X', 'Y']])

# %% [markdown]
# ## Create the Naive Prediction

# %%
naive_vals = train.groupby('Category').count().iloc[:,0]/train.shape[0]
n_rows = test.shape[0]

submission = pd.DataFrame(
    np.repeat(np.array(naive_vals), n_rows).reshape(39, n_rows).transpose(),
    columns=naive_vals.index)
submission.to_csv('naive_csv', index_label='Id')

# %%
submission
# Out:
# Category     ARSON   ASSAULT  BAD CHECKS  BRIBERY  BURGLARY  \
# 0         0.001727  0.087716    0.000464  0.00033  0.041794
# 1         0.001727  0.087716    0.000464  0.00033  0.041794
# 2         0.001727  0.087716    0.000464  0.00033  0.041794
# 3         0.001727  0.087716    0.000464  0.00033  0.041794
# 4         0.001727  0.087716    0.000464  0.00033  0.041794
# ...            ...       ...         ...      ...       ...
# 884257    0.001727  0.087716    0.000464  0.00033  0.041794
# 884258    0.001727  0.087716    0.000464  0.00033  0.041794
# 884259    0.001727  0.087716    0.000464  0.00033  0.041794
# 884260    0.001727  0.087716    0.000464  0.00033  0.041794
# 884261    0.001727  0.087716    0.000464  0.00033  0.041794
#
# Category  DISORDERLY CONDUCT  DRIVING UNDER THE INFLUENCE  DRUG/NARCOTIC  \
# 0                   0.004925                      0.00259       0.061571
# 1                   0.004925                      0.00259       0.061571
# 2                   0.004925                      0.00259       0.061571
# 3                   0.004925                      0.00259       0.061571
# 4                   0.004925                      0.00259       0.061571
# ...                      ...                          ...            ...
# 884257              0.004925                      0.00259       0.061571
# 884258              0.004925                      0.00259       0.061571
# 884259              0.004925                      0.00259       0.061571
# 884260              0.004925                      0.00259       0.061571
# 884261              0.004925                      0.00259       0.061571
#
# Category  DRUNKENNESS  EMBEZZLEMENT  ...  SEX OFFENSES NON FORCIBLE  \
# 0            0.004884      0.001329  ...                   0.000169
# 1            0.004884      0.001329  ...                   0.000169
# 2            0.004884      0.001329  ...                   0.000169
# 3            0.004884      0.001329  ...                   0.000169
# 4            0.004884      0.001329  ...                   0.000169
# ...               ...           ...  ...                        ...
# 884257       0.004884      0.001329  ...                   0.000169
# 884258       0.004884      0.001329  ...                   0.000169
# 884259       0.004884      0.001329  ...                   0.000169
# 884260       0.004884      0.001329  ...                   0.000169
# 884261       0.004884      0.001329  ...                   0.000169
#
# Category  STOLEN PROPERTY  SUICIDE  SUSPICIOUS OCC      TREA  TRESPASS  \
# 0                0.005181  0.00058        0.035849  0.000007  0.008356
# 1                0.005181  0.00058        0.035849  0.000007  0.008356
# 2                0.005181  0.00058        0.035849  0.000007  0.008356
# 3                0.005181  0.00058        0.035849  0.000007  0.008356
# 4                0.005181  0.00058        0.035849  0.000007  0.008356
# ...                   ...      ...             ...       ...       ...
# 884257           0.005181  0.00058        0.035849  0.000007  0.008356
# 884258           0.005181  0.00058        0.035849  0.000007  0.008356
# 884259           0.005181  0.00058        0.035849  0.000007  0.008356
# 884260           0.005181  0.00058        0.035849  0.000007  0.008356
# 884261           0.005181  0.00058        0.035849  0.000007  0.008356
#
# Category  VANDALISM  VEHICLE THEFT  WARRANTS  WEAPON LAWS
# 0          0.050907       0.061327  0.048126     0.009763
# 1          0.050907       0.061327  0.048126     0.009763
# 2          0.050907       0.061327  0.048126     0.009763
# 3          0.050907       0.061327  0.048126     0.009763
# 4          0.050907       0.061327  0.048126     0.009763
# ...             ...            ...       ...          ...
# 884257     0.050907       0.061327  0.048126     0.009763
# 884258     0.050907       0.061327  0.048126     0.009763
# 884259     0.050907       0.061327  0.048126     0.009763
# 884260     0.050907       0.061327  0.048126     0.009763
# 884261     0.050907       0.061327  0.048126     0.009763
#
# [884262 rows x 39 columns]

# %% [markdown]
# Submission score: 2.68015
